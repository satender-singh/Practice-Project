# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/DSData/master/happiness_score_dataset.csv')
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df.shape
# Out:
# (158, 12)

# %%
df.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df["Dystopia Residual"].unique()
# Out:
# array([2.51738, 2.70201, 2.49204, 2.46531, 2.45176, 2.61955, 2.4657 ,
#        2.37119, 2.26425, 2.26646, 3.08854, 3.17728, 2.5332 , 3.60214,
#        2.51011, 3.26001, 1.96961, 1.9757 , 2.41484, 2.24743, 1.96994,
#        2.47489, 3.19131, 1.88501, 2.84848, 2.11569, 2.67585, 1.55674,
#        2.21126, 2.836  , 2.67782, 2.32142, 2.85737, 2.31945, 2.43872,
#        2.12367, 1.6488 , 2.32323, 1.87634, 2.79094, 2.26882, 3.035  ,
#        2.74255, 2.23741, 2.24639, 1.68435, 2.21978, 2.53942, 1.73797,
#        2.02518, 2.82334, 3.10712, 2.18896, 2.24729, 1.61583, 2.44649,
#        2.32407, 2.5945 , 2.1309 , 1.86565, 1.88541, 2.75414, 2.09066,
#        2.27394, 2.32038, 1.59888, 1.88931, 2.43209, 2.76579, 1.86984,
#        1.76145, 0.65429, 1.58782, 1.86399, 2.20173, 2.08528, 2.2327 ,
#        2.89319, 1.63794, 2.00073, 3.10709, 1.87996, 2.10017, 1.8604 ,
#        2.6343 , 1.93129, 2.025  , 1.26462, 1.62215, 1.7536 , 2.11032,
# ...

# %%
df['Dystopia Residual'].nunique()
# Out:
# 158

# %%
for i in df.columns:
    print(df[i].value_counts())
    print('\n')
# Out:
# Switzerland    1
# Bangladesh     1
# Greece         1
# Lebanon        1
# Hungary        1
#               ..
# Kazakhstan     1
# Slovenia       1
# Lithuania      1
# Nicaragua      1
# Togo           1
# Name: Country, Length: 158, dtype: int64
#
#
# Sub-Saharan Africa                 40
# Central and Eastern Europe         29
# Latin America and Caribbean        22
# Western Europe                     21
# Middle East and Northern Africa    20
# Southeastern Asia                   9
# Southern Asia                       7
# Eastern Asia                        6
# North America                       2
# Australia and New Zealand           2
# Name: Region, dtype: int64
#
#
# 82     2
# 1      1
# 110    1
# 103    1
# 104    1
#       ..
# 54     1
# 55     1
# 56     1
# 57     1
# 158    1
# Name: Happiness Rank, Length: 157, dtype: int64
#
#
# 5.192    2
# 7.587    1
# 4.686    1
# 4.839    1
# 4.800    1
#         ..
# 5.855    1
# 5.848    1
# 5.833    1
# 5.828    1
# ...

# %%
df.shape[0]
# Out:
# 158

# %%
np.mean(df["Dystopia Residual"])
# Out:
# 2.098976772151899

# %%
categorical_col=[]
for i in df.dtypes.index:
    if df.dtypes[i]!='object':
        categorical_col.append(i)
print('categorical columns:', categorical_col)
# Out:
# categorical columns: ['Happiness Rank', 'Happiness Score', 'Standard Error', 'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)', 'Generosity', 'Dystopia Residual']

# %%
numerical_col=[]
for i in df.dtypes.index:
    if df.dtypes[i]!='object':
        numerical_col.append(i)
print("numerical colums:", numerical_col)
# Out:
# numerical colums: ['Happiness Rank', 'Happiness Score', 'Standard Error', 'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)', 'Generosity', 'Dystopia Residual']

# %%
df.nunique().to_frame("No. of unique values")
# Out:
#                                No. of unique values
# Country                                         158
# Region                                           10
# Happiness Rank                                  157
# Happiness Score                                 157
# Standard Error                                  153
# Economy (GDP per Capita)                        158
# Family                                          158
# Health (Life Expectancy)                        157
# Freedom                                         158
# Trust (Government Corruption)                   157
# Generosity                                      158
# Dystopia Residual                               158

# %%
df.drop("Region", axis=1, inplace=True)
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [44], in <cell line: 1>()
# ----> 1 df.drop("Region", axis=1, inplace=True)
#       2 df.head()
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
# ...

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
wh=sns.countplot(x='Dystopia Residual',data=df)
print(df['Dystopia Residual'].value_counts())
# Out:
# 2.51738    1
# 2.51767    1
# 1.80101    1
# 1.57059    1
# 1.24074    1
#           ..
# 2.24729    1
# 1.61583    1
# 2.44649    1
# 2.32407    1
# 1.56726    1
# Name: Dystopia Residual, Length: 158, dtype: int64

# %%
wh=sns.countplot(x='Generosity',data=df)
print(df['Generosity'].value_counts())
# Out:
# 0.29678    1
# 0.21222    1
# 0.00000    1
# 0.21854    1
# 0.12800    1
#           ..
# 0.11827    1
# 0.25328    1
# 0.02641    1
# 0.27815    1
# 0.16681    1
# Name: Generosity, Length: 158, dtype: int64

# %%
wh=sns.countplot(x='Trust (Government Corruption)',data=df)
print(df['Trust (Government Corruption)'].value_counts())
# Out:
# 0.32524    2
# 0.07625    1
# 0.01397    1
# 0.04582    1
# 0.02758    1
#           ..
# 0.03787    1
# 0.01031    1
# 0.19317    1
# 0.05989    1
# 0.10731    1
# Name: Trust (Government Corruption), Length: 157, dtype: int64

# %%
wh=sns.countplot(x='Freedom',data=df)
print(df['Freedom'].value_counts())
# Out:
# 0.66557    1
# 0.40820    1
# 0.07699    1
# 0.33916    1
# 0.32112    1
#           ..
# 0.51649    1
# 0.60855    1
# 0.21342    1
# 0.55475    1
# 0.36453    1
# Name: Freedom, Length: 158, dtype: int64

# %%
wh=sns.countplot(x='Health (Life Expectancy)',data=df)
print(df['Health (Life Expectancy)'].value_counts())
# Out:
# 0.92356    2
# 0.94143    1
# 0.60268    1
# 0.88213    1
# 0.83947    1
#           ..
# 0.66098    1
# 0.64368    1
# 0.87337    1
# 0.73128    1
# 0.28443    1
# Name: Health (Life Expectancy), Length: 157, dtype: int64

# %%
wh=sns.countplot(x='Family',data=df)
print(df['Family'].value_counts())
# Out:
# 1.34951    1
# 0.43106    1
# 0.92933    1
# 0.80001    1
# 1.20215    1
#           ..
# 1.12241    1
# 1.27385    1
# 1.25745    1
# 1.14184    1
# 0.13995    1
# Name: Family, Length: 158, dtype: int64

# %%
wh=sns.countplot(x='Economy (GDP per Capita)',data=df)
print(df['Economy (GDP per Capita)'].value_counts())
# Out:
# 1.39651    1
# 0.39753    1
# 1.15406    1
# 1.02564    1
# 1.12094    1
#           ..
# 1.12254    1
# 1.18498    1
# 1.14723    1
# 0.59325    1
# 0.20868    1
# Name: Economy (GDP per Capita), Length: 158, dtype: int64

# %%
wh=sns.countplot(x='Standard Error',data=df)
print(df['Standard Error'].value_counts())
# Out:
# 0.03780    2
# 0.03751    2
# 0.04394    2
# 0.05051    2
# 0.04934    2
#           ..
# 0.04114    1
# 0.04251    1
# 0.03843    1
# 0.05371    1
# 0.06727    1
# Name: Standard Error, Length: 153, dtype: int64

# %%
wh=sns.countplot(x='Happiness Score',data=df)
print(df['Happiness Score'].value_counts())
# Out:
# 5.192    2
# 7.587    1
# 4.686    1
# 4.839    1
# 4.800    1
#         ..
# 5.855    1
# 5.848    1
# 5.833    1
# 5.828    1
# 2.839    1
# Name: Happiness Score, Length: 157, dtype: int64

# %%
wh=sns.countplot(x='Happiness Rank',data=df)
print(df['Happiness Rank'].value_counts())
# Out:
# 82     2
# 1      1
# 110    1
# 103    1
# 104    1
#       ..
# 54     1
# 55     1
# 56     1
# 57     1
# 158    1
# Name: Happiness Rank, Length: 157, dtype: int64

# %%
plt.figure(figsize=(6,6),facecolor='white')
plotnumber=1
for col in numerical_col:
    if plotnumber<=4:
        wh=plt.subplot(3,3,plotnumber)
        sns.displot(df[col],color="m")
        plt.xlabel(col, fontsize=12)
        plt.yticks(rotation=0,fontsize=10)
plotnumber+=1
plt.tight_layout()

# %%
plt.title("comparision between Generosity and Dystopia Residual")
sns.stripplot(x="Generosity",y="Dystopia Residual",data=df)
plt.show()

# %%
plt.title("comparision between Trust (Government Corruption) and Dystopia Residual")
sns.stripplot(x="Trust (Government Corruption)",y="Dystopia Residual",data=df)
plt.show()

# %%
plt.title("comparision between Freedom and Dystopia Residual")
sns.stripplot(x="Freedom",y="Dystopia Residual",data=df)
plt.show()

# %%
plt.title("comparision between Health (Life Expectancy) and Dystopia Residual")
sns.stripplot(x="Health (Life Expectancy)",y="Dystopia Residual",data=df)
plt.show()

# %%
plt.title("comparision between Family and Dystopia Residual")
sns.stripplot(x="Family",y="Dystopia Residual",data=df)
plt.show()

# %%
plt.title("comparision between Economy (GDP per Capita) and Dystopia Residual")
sns.stripplot(x="Economy (GDP per Capita)",y="Dystopia Residual",data=df)
plt.show()

# %%
plt.title("comparision between Standard Error and Dystopia Residual")
sns.stripplot(x="Standard Error",y="Dystopia Residual",data=df)
plt.show()

# %%
plt.title("comparision between Happiness Score and Dystopia Residual")
sns.stripplot(x="Happiness Score",y="Dystopia Residual",data=df)
plt.show()

# %%
plt.title("comparision between Happiness Rank and Dystopia Residual")
sns.stripplot(x="Happiness Rank",y="Dystopia Residual",data=df)
plt.show()

# %%
sns.pairplot(df,hue="Dystopia Residual")
plt.show()

# %%
plt.figure()
plotnumber=1
for col in numerical_col:
    if plotnumber<=4:
        ax=plt.subplot(2,2,plotnumber)
        sns.boxplot(df[col])
    plotnumber+=1
plt.tight_layout()

# %%
df.skew()
# Out:
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,-1]
x
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587        0.324310                   1.39651  1.34951
# ...

# %%
y
# Out:
# 0      2.51738
# 1      2.70201
# 2      2.49204
# 3      2.46531
# 4      2.45176
#         ...
# 153    0.67042
# 154    1.63328
# 155    0.32858
# 156    1.83302
# 157    1.56726
# Name: Dystopia Residual, Length: 158, dtype: float64

# %%
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(x))
z.shape
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [42], in <cell line: 3>()
#       1 from scipy.stats import zscore
#       2 import numpy as np
# ----> 3 z=np.abs(zscore(x))
#       4 z.shape
#
# File ~\anaconda3\lib\site-packages\scipy\stats\stats.py:2474, in zscore(a, axis, ddof, nan_policy)
#    2406 def zscore(a, axis=0, ddof=0, nan_policy='propagate'):
#    2407     """
#    2408     Compute the z score.
#    2409
#    (...)
#    2472            [-0.91611681, -0.89090508,  1.4983032 ,  0.88731639, -0.5785977 ]])
#    2473     """
# -> 2474     return zmap(a, a, axis=axis, ddof=ddof, nan_policy=nan_policy)
#
# File ~\anaconda3\lib\site-packages\scipy\stats\stats.py:2544, in zmap(scores, compare, axis, ddof, nan_policy)
#    2542         isconst = np.apply_along_axis(_isconst, axis, a)
#    2543 else:
# -> 2544     mn = a.mean(axis=axis, keepdims=True)
# ...
